# %% [markdown]
# <a href="https://colab.research.google.com/github/romancgilbert/scratchpad/blob/main/nb_2026_01_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ds4e/scratchpad
# %run ./scratchpad/get_data.py
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 27 (delta 2), reused 0 (delta 0), pack-reused 23 (from 1)
# Receiving objects: 100% (27/27), 29.15 KiB | 14.58 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# ...
# Download complete
# Extracting data files...
# Data extracted

# %% [markdown]
# OK, let's see if this saves back the way I expect.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,3,5])
y = np.log(x)

plt.plot(x,y)
plt.show()

# %%
import pandas as pd

df = pd.read_csv('/content/data/airbnb_NYC.csv',
                 encoding='latin1')

df.head()
# Out:
#     Host Id Host Since                                Name Neighbourhood   \
# 0   5162530        NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899        NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626        NaN                Sunny Room in Harlem      Manhattan
# 3       500  6/26/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  6/26/2008            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
# ...

# %%
import pandas as pd
import seaborn as sns
import numpy as np
df = pd.read_csv('data/craigslist_cville_cars.csv', encoding='cp1252')
df.head()
# Out:
#    Unnamed: 0                                              title  price  \
# 0           0                      a sweet sedan avalon xle plus  24000
# 1           1  1998 gmc sierra 1500 sl truck auto rwd <103,00...   6950
# 2           2        gmc sierra 3500hd 6.6 duramax diesel dually  26000
# 3           3                              2007 chrysler sebring   2900
# 4           4                               2012 nissan versa sl   3500
#
#      year                                               link    brand   age
# 0     NaN  https://charlottesville.craigslist.org/cto/d/c...  missing   NaN
# 1  1998.0  https://charlottesville.craigslist.org/cto/d/l...      gmc  27.0
# 2     NaN  https://charlottesville.craigslist.org/cto/d/c...      gmc   NaN
# 3  2007.0  https://charlottesville.craigslist.org/cto/d/c...  missing  18.0
# 4  2012.0  https://charlottesville.craigslist.org/cto/d/c...  missing  13.0

# %%
price_nan = np.sum(df['price'].isna())
year_nan = np.sum(df['year'].isna())
print('Price NaN:', price_nan, 'Year NaN:', year_nan)
# Out:
# Price NaN: 0 Year NaN: 5

# %%
g = df.dropna()
g
# Out:
#     Unnamed: 0                                              title  price  \
# 1            1  1998 gmc sierra 1500 sl truck auto rwd <103,00...   6950
# 3            3                              2007 chrysler sebring   2900
# 4            4                               2012 nissan versa sl   3500
# 5            5   ford e-350 2003 quigley 4x4 ambulance camper van  55000
# 6            6                              2012 lexus rx450h awd  10950
# 7            7                                   2008 toyota rav4   5000
# 8            8                                 2013 toyota avalon  17000
# 9            9  2014 subaru outback premium awd or 2009 honda ...   3900
# 10          10                 1963 /1965 triumph tr4 convertible   2250
# 11          11                       2017 hyundai santa fe sports   9200
# 12          12                                   1989 xj wrangler   5999
# 13          13  2013 jeep grand cherokee - overland - 4wd (rep...   9500
# ...

# %%
g = sns.relplot(df, x='year', y='price', kind='line', height=5, aspect=2.5)

g.set(ylim=(0, 50000))
